# %% [markdown]
# # Consume messages from an Aiven for Apache Kafka®️ partitioned topic
#
# In this notebook you will learn how to consume messages from an Apache Kafka topic with two partitions (created in [3-produce-partitioned-topic.ipynb](3-produce-partitioned-topic.ipynb)).
#
# ![Consume messages from an Apache Kafka Topic](../img/4%20-%20multiple%20kafka%20consumers%20one%20consumer%20group%20python.png)
#
# > [!NOTE]
# >
# > _If you haven't yet set up your Kafka credentials, complete [0-setup.ipynb](0-setup.ipynb) first._
# >
# > You will need the `pizzasPartitioned` topic created by [3-produce-partitioned-topic.ipynb](3-produce-partitioned-topic.ipynb).

# %% [markdown]
# ---
#
# ## Create an Apache Kafka®️ Consumer
#
# The next step is to configure the Kafka Consumer. let's recall in the previous notebook. That `Francesco's` message was sent to partition `0` and `Adele's` message was in partition `1`.
#
# ```python
# producer.produce(
#     "pizzasPartitioned",
#     key={"id":1},
#     value={"id":1, "name":"👨 Francesco", "pizza":"Margherita 🍕"},
#     partition=0
# )
#
# producer.produce(
#     "pizzasPartitioned",
#     key={"id":2},
#     value={"id":2, "name":"👩 Adele", "pizza":"Hawaii 🍕+🍍+🥓"},
#     partition=1
# )
# ```
#
# In `2-consume.ipynb` we saw that all the topics are all loaded. We're going to create two consumers that belong to the group `pizzaaioli`. `consumer_0` will consume messages in partition `0` and `consumer_1` consumes messages in partition `1`.

# %%
import json
import os

from confluent_kafka import Consumer, TopicPartition
from dotenv import load_dotenv

load_dotenv()

KAFKA_SERVICE_URI = os.getenv("KAFKA_SERVICE_URI")
topic = "pizzasPartitioned"
conf = {
    'bootstrap.servers': KAFKA_SERVICE_URI,
    'client.id': 'myclient',
    'group.id': 'pizzaioli',
    'security.protocol': 'SSL',
    'ssl.ca.location': '../sslcerts/ca.pem',
    'ssl.certificate.location': '../sslcerts/service.cert',
    'ssl.key.location': '../sslcerts/service.key',
    'auto.offset.reset': 'earliest',
}

orders_consumer_northern_store = Consumer(conf)
orders_consumer_northern_store.assign([TopicPartition(topic, 0)])

orders_consumer_southern_store = Consumer(conf)
orders_consumer_southern_store.assign([TopicPartition(topic, 1)])

# %% [markdown]
# ## Consume messages from the `pizzasPartitioned` topic
#
# Review and start the code block below. While the block is running. Use the **LAST** block in `3-produce-partitioned-topic.ipynb` to produced more partitioned samples.

# %%
from confluent_kafka import Consumer, KafkaException
from rich.console import Console

console = Console()

def display_orders(consumer: Consumer, label: str, style: str = "bold", count: int = 1):
    finished = False
    local_count = 0
    while not finished:
        if (msg := consumer.poll(timeout=1.0)) is None:
            continue
        elif msg.error():
            raise KafkaException(msg.error())
        else:
            key = json.loads(msg.key().decode()) if msg.key() else None
            value = json.loads(msg.value().decode())
            console.print(f"Checking Partition {label} \n" + "-" * 10, style=style)
            console.print(f"[{style}]{msg.partition()}:{msg.offset()}: {key}:{value}[/{style}]\n\n")
            local_count += 1
            finished = local_count == count

console.print("Run the last block from `3-produce-partitioned-topic.ipynb`.")
display_orders(orders_consumer_northern_store, "Northern Store", "bold red")
display_orders(orders_consumer_southern_store, "Southern Store", "bold green")
# Out:
# Run the last block from `3-produce-partitioned-topic.ipynb`.
# Checking Partition Northern Store
# ----------
# 0:0: {'id': 1}:{'id': 1, 'name': '👨 Francesco', 'pizza': 'Margherita 🍕'}
# Checking Partition Southern Store
# ----------
# 1:0: {'id': 2}:{'id': 2, 'name': '👩 Adele', 'pizza': 'Hawaii 🍕+🍍+🥓', 'qty': 1}
# %5|1785241961.354|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61136ms, timeout #0)
# %4|1785241961.354|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785244211.987|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61364ms, timeout #0)
# %4|1785244211.987|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785247783.983|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61127ms, timeout #0)
# %4|1785247783.983|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785248805.213|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61319ms, timeout #0)
# %4|1785248805.213|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785251393.162|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 60534ms, timeout #0)
# %4|1785251393.163|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785256989.061|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 61214ms, timeout #0)
# %4|1785256989.061|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785256989.066|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61154ms, timeout #0)
# %4|1785256989.066|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785260965.305|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 60820ms, timeout #0)
# %4|1785260965.305|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785260965.305|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 60722ms, timeout #0)
# %4|1785260965.305|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785264422.732|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 61349ms, timeout #0)
# %4|1785264422.732|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785264422.762|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 61142ms, timeout #0)
# %4|1785264422.762|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785266775.761|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 209094ms, timeout #0)
# %4|1785266775.763|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785266775.761|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 208982ms, timeout #0)
# %4|1785266775.764|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785267067.489|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 244871ms, timeout #0)
# %4|1785267067.489|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785267067.490|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 244820ms, timeout #0)
# %4|1785267067.490|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785267074.655|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 287571ms in state UP)
# %4|1785267074.657|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 287602ms in state UP)
# %5|1785267517.484|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 402647ms, timeout #0)
# %4|1785267517.484|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785267518.160|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 403506ms, timeout #0)
# %4|1785267518.160|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785267524.506|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 449320ms in state UP, 1 identical error(s) suppressed)
# %6|1785267526.976|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 451804ms in state UP, 1 identical error(s) suppressed)
# %5|1785267918.464|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 354627ms, timeout #0)
# %4|1785267918.464|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785267918.790|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 354733ms, timeout #0)
# %4|1785267918.790|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785267927.670|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 402579ms in state UP, 1 identical error(s) suppressed)
# %4|1785267927.711|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 399416ms in state UP, 1 identical error(s) suppressed)
# %5|1785268316.455|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 351059ms, timeout #0)
# %4|1785268316.455|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785268316.466|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 351374ms, timeout #0)
# %4|1785268316.466|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785268323.824|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 395450ms in state UP, 1 identical error(s) suppressed)
# %4|1785268324.078|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 395720ms in state UP, 1 identical error(s) suppressed)
# %5|1785268521.941|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 96937ms, timeout #0)
# %4|1785268521.941|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785268521.945|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 97367ms, timeout #0)
# %4|1785268521.945|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785268871.411|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 302489ms, timeout #0)
# %4|1785268871.411|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785268871.458|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 302586ms, timeout #0)
# %4|1785268871.459|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785268879.220|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 554554ms in state UP, 1 identical error(s) suppressed)
# %4|1785268879.968|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 555608ms in state UP, 1 identical error(s) suppressed)
# %5|1785269072.666|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 154384ms, timeout #0)
# %4|1785269072.666|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785269072.690|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 154544ms, timeout #0)
# %4|1785269072.690|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785269383.993|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 128262ms, timeout #0)
# %4|1785269383.993|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785269384.021|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 128320ms, timeout #0)
# %4|1785269384.021|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785269391.586|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 511242ms in state UP, 1 identical error(s) suppressed)
# %4|1785269391.592|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 511092ms in state UP, 1 identical error(s) suppressed)
# %4|1785269414.105|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Connection setup timed out in state CONNECT (after 30083ms in state CONNECT)
# %4|1785269414.371|FAIL|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Connection setup timed out in state SSL_HANDSHAKE (after 26122ms in state SSL_HANDSHAKE)
# %5|1785269752.846|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 322554ms, timeout #0)
# %4|1785269752.846|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785269752.965|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 322873ms, timeout #0)
# %4|1785269752.965|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785269761.041|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 369171ms in state UP, 1 identical error(s) suppressed)
# %4|1785269761.098|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 369224ms in state UP, 1 identical error(s) suppressed)
# %5|1785270233.046|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 433696ms, timeout #0)
# %4|1785270233.046|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785270233.535|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 434236ms, timeout #0)
# %4|1785270233.535|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785270241.799|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 480213ms in state UP, 1 identical error(s) suppressed)
# %4|1785270241.804|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 480286ms in state UP, 1 identical error(s) suppressed)
# %4|1785270264.383|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Connection setup timed out in state SSL_HANDSHAKE (after 22442ms in state SSL_HANDSHAKE)
# %5|1785270419.392|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 139516ms, timeout #0)
# %4|1785270419.392|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785270419.580|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 139928ms, timeout #0)
# %4|1785270419.580|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785270449.494|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Connection setup timed out in state SSL_HANDSHAKE (after 27135ms in state SSL_HANDSHAKE)
# %4|1785270450.295|FAIL|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Connection setup timed out in state SSL_HANDSHAKE (after 29180ms in state SSL_HANDSHAKE)
# %5|1785270752.848|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 287092ms, timeout #0)
# %4|1785270752.848|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1785270752.858|FAIL|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Failed to connect to broker at 68.183.100.239:28284: Can't assign requested address (after 10ms in state CONNECT)
# %5|1785270752.871|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 287365ms, timeout #0)
# %4|1785270752.871|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785270761.294|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 518736ms in state UP, 1 identical error(s) suppressed)
# %4|1785270761.314|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 518478ms in state UP, 1 identical error(s) suppressed)
# %4|1785270783.026|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Connection setup timed out in state SSL_HANDSHAKE (after 30051ms in state SSL_HANDSHAKE)
# %4|1785270784.212|FAIL|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Connection setup timed out in state SSL_HANDSHAKE (after 27066ms in state SSL_HANDSHAKE)
# %5|1785273603.921|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 2804682ms, timeout #0)
# %4|1785273603.921|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785273604.474|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 2805241ms, timeout #0)
# %4|1785273604.474|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1785273604.492|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Failed to connect to broker at 142.93.78.5:28284: Network is unreachable (after 17ms in state CONNECT)
# %3|1785273605.496|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Failed to connect to broker at 142.93.78.5:28284: Network is unreachable (after 2ms in state CONNECT, 1 identical error(s) suppressed)
# %4|1785273611.445|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 2848647ms in state UP, 1 identical error(s) suppressed)
# %4|1785273611.999|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 2848997ms in state UP, 1 identical error(s) suppressed)
# %5|1785277490.495|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 3839636ms, timeout #0)
# %4|1785277490.495|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785277490.733|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 3839938ms, timeout #0)
# %4|1785277490.733|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785277497.355|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 3884554ms in state UP, 1 identical error(s) suppressed)
# %4|1785277497.552|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 3884905ms in state UP, 1 identical error(s) suppressed)
# %5|1785278494.294|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 957195ms, timeout #0)
# %4|1785278494.294|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785278494.383|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 956905ms, timeout #0)
# %4|1785278494.383|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785278502.401|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 1004030ms in state UP, 1 identical error(s) suppressed)
# %4|1785278504.966|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 1006799ms in state UP, 1 identical error(s) suppressed)
# %5|1785283071.494|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 4450182ms, timeout #0)
# %4|1785283071.494|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785283071.946|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 4450634ms, timeout #0)
# %4|1785283071.946|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785283079.695|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 4575955ms in state UP, 1 identical error(s) suppressed)
# %4|1785283081.154|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 4575745ms in state UP, 1 identical error(s) suppressed)
# %5|1785288915.406|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 5797409ms, timeout #0)
# %4|1785288915.406|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785288915.570|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 5797286ms, timeout #0)
# %4|1785288915.570|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785288921.721|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 5841400ms in state UP, 1 identical error(s) suppressed)
# %4|1785288922.052|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 5840456ms in state UP, 1 identical error(s) suppressed)
# %5|1785294740.422|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 5778228ms, timeout #0)
# %4|1785294740.422|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785294749.579|FAIL|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 5826195ms in state UP)
# %4|1785294750.123|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 5826676ms in state UP, 1 identical error(s) suppressed)
# %6|1785294750.123|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 5826665ms in state UP, 1 identical error(s) suppressed)
# %5|1785297896.381|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 3109359ms, timeout #0)
# %4|1785297896.381|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785297904.358|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 3151590ms in state UP, 1 identical error(s) suppressed)
# %4|1785297904.393|FAIL|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 3151346ms in state UP)
# %4|1785297904.514|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 3151626ms in state UP, 1 identical error(s) suppressed)
# %5|1785298969.482|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 1026129ms, timeout #0)
# %4|1785298969.482|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785298969.585|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 1026076ms, timeout #0)
# %4|1785298969.585|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785298977.817|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 1072833ms in state UP, 1 identical error(s) suppressed)
# %4|1785298977.818|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 1072920ms in state UP, 1 identical error(s) suppressed)
# %5|1785304796.601|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 5780619ms, timeout #0)
# %4|1785304796.601|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785304796.785|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 5780802ms, timeout #0)
# %4|1785304796.785|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785304802.160|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 5822963ms in state UP, 1 identical error(s) suppressed)
# %4|1785304803.178|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 5824403ms in state UP, 1 identical error(s) suppressed)
# %5|1785306229.336|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 1385974ms, timeout #0)
# %4|1785306229.336|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785306229.456|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 1386094ms, timeout #0)
# %4|1785306229.456|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785306237.253|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 1434715ms in state UP, 1 identical error(s) suppressed)
# %4|1785306238.046|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 1434094ms in state UP, 1 identical error(s) suppressed)
# %5|1785309889.690|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 3613409ms, timeout #0)
# %4|1785309889.690|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785309889.748|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 3613452ms, timeout #0)
# %4|1785309889.748|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785309897.727|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 3658493ms in state UP, 1 identical error(s) suppressed)
# %4|1785309897.862|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 3658544ms in state UP, 1 identical error(s) suppressed)
# %5|1785313549.311|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 3612949ms, timeout #0)
# %4|1785313549.311|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785313549.370|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 3613068ms, timeout #0)
# %4|1785313549.370|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785313559.579|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 3659849ms in state UP, 1 identical error(s) suppressed)
# %4|1785313560.068|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 3660296ms in state UP, 1 identical error(s) suppressed)
# %5|1785316314.745|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 2718420ms, timeout #0)
# %4|1785316314.745|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785316315.050|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 2718520ms, timeout #0)
# %4|1785316315.050|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785316323.857|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 2762531ms in state UP, 1 identical error(s) suppressed)
# %4|1785316324.143|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 2763001ms in state UP, 1 identical error(s) suppressed)
# %5|1785316771.749|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 409967ms, timeout #0)
# %4|1785316771.749|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %5|1785316771.749|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out FetchRequest in flight (after 409948ms, timeout #0)
# %4|1785316771.749|REQTMOUT|myclient#consumer-2| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %4|1785316778.452|FAIL|myclient#consumer-2| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Disconnected: connection reset by peer (after 454110ms in state UP, 1 identical error(s) suppressed)
# %4|1785316778.455|FAIL|myclient#consumer-1| [thrd:ssl://68.183.100.239:28284/2]: ssl://68.183.100.239:28284/2: Disconnected: connection reset by peer (after 453912ms in state UP, 1 identical error(s) suppressed)
# %5|1785335623.479|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out FetchRequest in flight (after 60844ms, timeout #0)
# %4|1785335623.479|REQTMOUT|myclient#consumer-1| [thrd:ssl://142.93.78.5:28284/1]: ssl://142.93.78.5:28284/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests

# %% [markdown]
# ### Excellent Work! 🥳
#
# In this notebook:
#
#  - We created multiple consumers.
#  - We consumed our messages from the Northern and Southern Store Partitions
#
# In the next notebook we'll expand on this concept by creating multiple consumer groups so that we can adjust how partitions are consumed.
#
# Select the [next notebook](5-new-consumer-group.ipynb) or click the button below to continue.
#
# [![Button to Part 5](https://img.shields.io/badge/5-Working%20Multiple%20Consumer%20Groups-a03586?style=for-the-badge&labelColor=ec6147)](5-new-consumer-group.ipynb)
